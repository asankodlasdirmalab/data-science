# %% [markdown]
# # NumPy Dərs 4 Tapşırıqlar

# %% [markdown]
# ## Tapşırıq 1 — Maaş artımı
# Bir şirkətdə işçilərin maaşlarına 200 manat əlavə edin

# %%
import numpy as np

salaries = np.array([800, 950, 1200, 1500, 1800])

# %% [markdown]
# ## Tapşırıq 2 — Endirim kampaniyası
# Mağazada bütün məhsullara 15 manat endirim tətbiq edin

# %%
import numpy as np
qiymetler = np.array([120, 80, 250, 60, 150])

# %% [markdown]
# ## Tapşırıq 3 — Satış gəliri
# Satılan məhsul sayı və məhsulların qiymətləri verilib. Hər məhsuldan əldə olunan gəliri hesablayın (bir birinə vur nəticəni göstər)

# %%
import numpy as np
quantity = np.array([5, 3, 8, 2])
price = np.array([20, 50, 15, 100])
gelir = # burdan yaz

# %% [markdown]
# ## Tapşırıq 4 — Sürət hesablanması
# Avtomobillərin qət etdiyi məsafə və sərf etdikləri vaxt verilib. Hər avtomobilin orta sürətini tapın (orta suret = məsafə / vaxt)

# %%
import numpy as np
distance = np.array([120, 240, 180, 300])
time = np.array([2, 4, 3, 5])
orta_suret = # burdan yaz

# %% [markdown]
# ## Tapşırıq 5 — Kvadrat kök və sahə
# Aşağıdakı kvadratların sahələri verilib. Hər kvadratın uzunluğunu tapın. (teref = sahe nin kökü)

# %%
import numpy as np
saheler = np.array([25, 64, 100, 144, 225])

# %% [markdown]
# ## Tapşırıq 6 — Enerji hesablanması
# Aşağıdakı ədədlərin kvadratını hesablayın.

# %%
import numpy as np
ededler = np.array([2, 4, 6, 8, 10])

# %% [markdown]
# ## Tapşırıq 7 — Temperatur
# Temperaturdan fərqləri verilib. Onları müsbətə çevir

# %%
import numpy as np
tempratur_ferqleri = np.array([-5, 3, -8, 12, -2, 7])
musbet_tempratur_ferqleri = # burdan yaz

# %% [markdown]
# ## Tapşırıq 8 — İmtahan nəticələri
# Şagirdlərin ballarına 10 bal əlavə edin və sonra yeni balların kvadratını hesablayın

# %%
import numpy as np
ballar = np.array([55, 68, 72, 80, 91])

# %% [markdown]
# ## Tapşırıq 9 — Futbol statistikası
# Bir futbolçunun 5 oyunda vurduğu qollar verilmişdir. Qolları 2 ilə vuraraq xal dəyəri yaradın və sonra hər oyunun xal dəyərinin kvadrat kökünü hesablayın

# %%
import numpy as np
gollar = np.array([1, 2, 0, 3, 4])

# %% [markdown]
# ## Tapşırıq 10 — Onlayn mağaza
# Bir mağazada məhsulların qiymətləri verilmişdir: `qiymetler = np.array([50, 120, 75, 200, 90])`
#
# Aşağıdakı əməliyyatları ardıcıl olaraq yerinə yetirin.

# %%
qiymetler = np.array([50, 120, 75, 200, 90])
print("İlkin qiymətlər:", qiymetler)

# 1. Bütün qiymətlərə 10 manat əlavə edin.
# cavabi burdan yaz

# 2. Sonra bütün qiymətlərdən 5 manat çıxın.
# cavabi burdan yaz

# 3. Yeni qiymətləri 2 ilə vurun.
# cavabi burdan yaz

# 4. Yeni qiymətləri 10-a bölün.
# cavabi burdan yaz

# 5. Qiymətlərin kvadratını hesablayın.
# cavabi burdan yaz

# 6. Qiymətlərin kvadrat kökünü hesablayın.
# cavabi burdan yaz

# 7. Qiymətləri mənfi ədədə çevirib modulunu tapın.
# cavabi burdan yaz
