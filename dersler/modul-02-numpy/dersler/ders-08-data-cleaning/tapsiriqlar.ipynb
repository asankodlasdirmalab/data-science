# %% [markdown]
# # NumPy Dərs 8: Data cleaning — Tapşırıqlar

# %% [markdown]
# ### Tapşırıq 1
# aşağıdakı `data` arrayında boş dəyər (`NaN`) dəyərləri tapın `np.isnan()` və terminalda göstərin

# %%
import numpy as np

data = np.array([22.4, np.nan, 25.1, np.nan, 21.8, 24.0])

# %% [markdown]
# ### Tapşırıq 2
# aşağıdakı `data` arrayındə boş olmayan bütün ədədləri Boolean Indexing (Tərs maskalama `~`) üsulu ilə filterləyib ayrıca bir array olaraq göstərin

# %%
import numpy as np

sensor_data = np.array([22.4, np.nan, 25.1, np.nan, 21.8, 24.0])

# %% [markdown]
# ### Tapşırıq 3
# aylıq satışları göstərən `satislar` arrayı verilib. `NaN` dəyərlərini nəzərə almadan satışların ortalama dəyərini hesablayın

# %%
import numpy as np

satislar = np.array([120, 150, np.nan, 90, 200, np.nan, 110])

# %% [markdown]
# ### Tapşırıq 4
# `temperaturlar` arrayının standard deviation-ı hesablayın

# %%
import numpy as np

temperaturlar = np.array([18, 22, np.nan, 25, 19, np.nan])

# %% [markdown]
# ### Tapşırıq 5
# aşağıdakı datada boş qalan xanalara defolt olaraq `0` dəyərini verin

# %%
import numpy as np

X = np.array([5.5, np.nan, 12.3, np.nan, 8.0])

# %% [markdown]
# ### Tapşırıq 6
# aşağıdakı boş dəyərləri `0` deyil, `-4` ilə əvəzləyin

# %%
import numpy as np

X = np.array([5.5, np.nan, 12.3, np.nan, 8.0])

# %% [markdown]
# ### Tapşırıq 7
# `pikseller` arrayı verilib. datada min `0` ve max `255` arasında olmalıdır. Data təmizləyin və ekranda göstərin

# %%
import numpy as np

pikseller = np.array([-20, 105, 300, 255, 45, -5, 180])

# %% [markdown]
# ### Tapşırıq 8
# 1. `məlumatlar` arrayında orta dəyərini tapın.
# 2. Tapılan orta dəyəri `NaN` dəyərləri ilə əvəz edin
# 3. Sonda, əldə olunan datanı `10` ilə `50` aralığında yazın

# %%
import numpy as np

melumatlar = np.array([5, 12, np.nan, 85, np.nan, 40, -15])
