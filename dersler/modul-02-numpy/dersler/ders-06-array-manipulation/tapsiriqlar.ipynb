# %% [markdown]
# # Dərs 6: Array Manipulation — Tapşırıqlar

# %% [markdown]
# ### Tapşırıq 1
# İki fərqli mağazanın gündəlik satış miqdarlarını göstərən 1D (birtərəfli) array-ləri `np.concatenate` funksiyası ilə tək bir array-də ardıcıl birləşdirin

# %%
import numpy as np

magaza_A = np.array([10, 15, 20])
magaza_B = np.array([30, 35, 40])

# %% [markdown]
# ### Tapşırıq 2
# Iki fərqli tələbənin 3 fənn üzrə balları var. Bu 1D array-ləri şaquli olaraq (alt-alta) düzərək 2D array yaradın

# %%
import numpy as np

telebe_1 = np.array([85, 90, 75])
telebe_2 = np.array([60, 70, 80])

# %% [markdown]
# ### Tapşırıq 3
# İki fərqli cihazdan gələn temperatur göstəricilərini üfüqi olaraq (yan-yana) birləşdirərək tək bir uzun array əldə edin

# %%
import numpy as np

cihaz_1 = np.array([22, 24, 25])
cihaz_2 = np.array([21, 23, 24])

# %% [markdown]
# ### Tapşırıq 4
# Verilmiş iki fərqli 2D arrayı sətirlər üzrə (`axis=0`) aşağıya doğru birləşdirin

# %%
import numpy as np

matrix1 = np.array([[1, 2], [3, 4]])
matrix2 = np.array([[5, 6], [7, 8]])

# %% [markdown]
# ### Tapşırıq 5
# Verilmiş iki fərqli 2D arrayı sətirlər üzrə (`axis=0`) aşağıya doğru birləşdirin

# %%
import numpy as np

matrix1 = np.array([[1, 2], [3, 4]])
matrix2 = np.array([[5, 6], [7, 8]])

# %% [markdown]
# ### Tapşırıq 6
# 1. 0-dan 12-yə qədər array yaradın (əl ilə yazmadan)
# 2. Həmin arrayı ibarət olan bir array-i `np.split` funksiyası ilə 4 bərabər hissəyə bölün və hissələri terminalda göstərin

# %%
import numpy as np

# %% [markdown]
# ### Tapşırıq 7
# Verilmiş arrayın yalnız sonuncu sütununu götürün (Slicing - Dərs 3) və həmin kəsilmiş hissəni özü ilə alt-alta birləşdirərək yeni array yaradın

# %%
import numpy as np

matris = np.array([[10, 20, 30], 
                   [40, 50, 60]])

# %% [markdown]
# ### Tapşırıq 8
# Matrixin hər sətirinin ortalamasını (Mean - Dərs 5) tapın. Sonra bu ortalama dəyərlərini matrixə yeni bir sütun kimi ən sağa əlavə edin. (İpucu: `np.newaxis` və `np.hstack` istifadə edin)

# %%
import numpy as np

matris = np.array([[10, 20], 
                   [30, 40]])

# %% [markdown]
# ### Tapşırıq 9
# İki fərqli 1D array-i əvvəlcə 2x3 ölçülü matrixə çevirin (reshape - Dərs 2), daha sonra isə `np.stack` funksiyası ilə 3D array halına gətirin.

# %%
import numpy as np

arr1 = np.array([1, 2, 3, 4, 5, 6])
arr2 = np.array([7, 8, 9, 10, 11, 12])

# %% [markdown]
# ### Tapşırıq 10
# Arraydakı bütün elementləri 2-yə vurun. Daha sonra `elave_setir` array-inin hər bir elementinə 5 əlavə edin (Broadcasting) və  nəticəni alt-alta birləşdirin.

# %%
import numpy as np

matris = np.array([[1, 2, 3], 
                   [4, 5, 6]])
elave_setir = np.array([10, 20, 30])
