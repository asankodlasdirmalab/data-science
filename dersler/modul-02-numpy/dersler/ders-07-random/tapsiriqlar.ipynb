# %% [markdown]
# # NumPy Dərs 7: Random — Tapşırıqlar

# %% [markdown]
# ### Tapşırıq 1
# `np.random.rand()` funksiyasından istifadə edərək `3x4` ölçülü, `[0.0, 1.0)` aralığında təsadüfi float ədədlərdən ibarət 2D array yaradın

# %%
# kod burada

# %% [markdown]
# ### Tapşırıq 2
# `10` ilə `100` arasında (100 daxil olmaqla) random int ədədlərdən ibarət 15 elementli 1D array yaradın

# %%
# kod burda

# %% [markdown]
# ### Tapşırıq 3
# `a` və `b` matrixlərini `@` operatoru ilə bir-birinə vurun

# %%
import numpy as np

a = np.array([[1, 2], 
              [3, 4]])

b = np.array([[5, 6], 
              [7, 8]])

# %% [markdown]
# ### Tapşırıq 4
#  1. 20 elementli (mənfi ədədlər daxil) random 1D array yaradın
#  2. Bu array-in içindəki mənfi olan bütün ədədləri Boolean Indexing ilə filterləyib ekranda göstərin

# %%
# kod burda

# %% [markdown]
# ### Tapşırıq 5
# Verilmiş `mehsullar` siyahısının içindən təsadüfi və təkrarlanmayan3 fərqli məhsulları seçin

# %%
import numpy as np

mehsullar = np.array(["Telefon", "Laptop", "Planşet", "Saat", "Qulaqlıq", "Televizor"])

# %% [markdown]
# ### Tapşırıq 6
# `v = [2, -3, 6]` vektorunun həndəsi uzunluğunu (modulunu) hesablayın

# %%
v = [2, -3, 6]

# %% [markdown]
# ### Tapşırıq 7
# 1. Ortalaması  500, meyilliyi 12 olan 1000 elementli bir data yaradın
# 2. Həmin datanın (`mean`) dəyərini tapın

# %%
# kod burda

# %% [markdown]
# ### Tapşırıq 8
# 1.`1`-dən `6`-ya qədər (6 daxil olmaqla) ədədlərdən ibarət 1D array yaradın (random olmayan)
# 2. Həmin datanı `2x3` matrisinə çevirin.
# 3. `10` ilə `16` arasında (16 daxil deyil) ardıcıl ədədlərdən ibarət 1D array yaradın (random olmayan)
# 4. Həmin datanı `3x2` matrisinə çevirin
# 5. Bu iki matrixi `@` operatoru ilə bir-birinə vurun

# %%
# kod burda

# %% [markdown]
# ### Tapşırıq 9
# `matrix_yoxla` adlı funksiya yazın. Funksiya parametr olaraq iki matris qəbul etməlidir. Əgər birinci matrixin sütun sayı (cols) ikincinin sətir sayına (rows) bərabərdirsə, onda həmin matrixlərin hasilini tapın (`@`). Bərabər deyilsə, "Xəta: Ölçülər uyğun deyil!" mesajını göstərsin

# %%
# kod burda
