# %% [markdown]
# # NumPy Dərs 5 Tapşırıqlar

# %% [markdown]
# ### Tapşırıq 1 — Satış cəmi
# 1 həftəlik satışlar verilib. Ümumi satış sayını tapın.

# %%
import numpy as np
sales = np.array([12, 18, 10, 25, 30, 15, 20])

# %% [markdown]
# ### Tapşırıq 2 — Orta satış
# satışların orta gündəlik dəyərini hesablayın.

# %%
import numpy as np
sales = np.array([12, 18, 10, 25, 30, 15, 20])

# %% [markdown]
# ### Tapşırıq 3
# Bir şirkətdə maaşlar verilib. Orta maaşı tapın.

# %%
import numpy as np
salaries = np.array([800, 900, 1000, 1200, 5000])

# %% [markdown]
# ### Tapşırıq 4 — Ən yaxşı oyunçu
# Futbolçuların vurduğu qollar verilib. Ən çox qol vuranı tapın.

# %%
import numpy as np
goals = np.array([3, 1, 5, 2, 4])

# %% [markdown]
# ### Tapşırıq 5 — Ən zəif nəticə (min)
# Şagirdlərin ballarını verilib. Ən aşağı balı tapın.

# %%
import numpy as np
scores = np.array([55, 70, 45, 90, 60])

# %% [markdown]
# ### Tapşırıq 6
# Eyni ballarda ən aşağı nəticənin indeksini tapın.

# %%
import numpy as np
scores = np.array([55, 70, 45, 90, 60])

# %% [markdown]
# ### Tapşırıq 7
# Ən çox qol vuran oyunçunun indeksini tapın.

# %%
import numpy as np
goals = np.array([3, 1, 5, 2, 4])

# %% [markdown]
# ### Tapşırıq 8 — Variance (dağınıqlıq)
# Bir sinifin nəticələri verilib. Nəticələrin nə qədər dağınıq olduğunu tapın.

# %%
import numpy as np
scores = np.array([78, 79, 80, 81, 82])

# %% [markdown]
# ### Tapşırıq 9 — Std
# Eyni sinif üçün nəticələrin ortadan orta uzaqlığını tapın.

# %%
import numpy as np
scores = np.array([78, 79, 80, 81, 82])

# %% [markdown]
# ### Tapşırıq 10
# Bir şirkətin aylıq satışları verilib:
# `sales = np.array([100, 120, 90, 150, 200, 80, 110])`
#
# Bütün analiz addımlarını icra edək:

# %%
import numpy as np
sales_project = np.array([100, 120, 90, 150, 200, 80, 110])

# 1. umumi satış

# 2. orta satış

# 3. median satış

# 4. en yuksek satış

# 5. Ən yüksək satış

# 6. Ən aşağı satış

# 7. Variance

# 8. Std (standard deviation)
