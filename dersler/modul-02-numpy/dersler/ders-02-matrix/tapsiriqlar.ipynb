# %% [markdown]
# # NumPy Dərs 2 Tapsiriqlar

# %% [markdown]
# ### Tapşırıq 1
# 1-dən 12-yə qədər tam ədədlərdən ibarət (3, 4) ölçülü 2D NumPy array yaradın.
# `.shape`  istifadə edərək onun formasını göstərin

# %%
import numpy as np

#

# %% [markdown]
# ### Tapşırıq 2
#
# Tapşırıq 1-də yaradılan arrayın shape-ini (2, 6) şəklində dəyişdirin `.reshape()` metodundan istifadə edin və terminalda göstərin

# %%
#

# %% [markdown]
# ### Tapşırıq 3: flatten və ravel
#
# Həmin arrayı `.flatten()` və `.ravel()` metodlarından istifadə edərək 1D arraya çevirin

# %%
#

# %% [markdown]
# ### Tapşırıq 4:
#
# Arrayın Orijinal (3, 4) matrisinizin sətir və sütunlarının yerini dəyişdirin
# `.transpose()`

# %%
#
