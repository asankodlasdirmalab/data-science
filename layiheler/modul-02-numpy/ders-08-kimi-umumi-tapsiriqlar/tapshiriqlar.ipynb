# %% [markdown]
# # NumPy — Ümumi Tapşırıqlar (Dərs 7-ə kimi)

# %% [markdown]
# ### Tapşırıq 1
#
# mağazada 5 məhsulun qiyməti var: `12.5, 8.99, 45.0, 3.75, 22.0`
#
# Bu qiymətləri NumPy array-inə çevir. Sonra array-in tipini, ölçüsünü və element sayını yaz.

# %%
# Kodunu bura yaz:

# %% [markdown]
# ### Tapşırıq 2
#
# 8-dənə qutu yarat array kimi, hamısı boşdur. Belə bir data yarat

# %%
# Kodunu bura yaz:

# %% [markdown]
# ### Tapşırıq 3
#
# Bir işçi hər gün 1 saat işləyir. 7 günlük iş həftəsini hazırla.
#
# Sonra ümumi işlənmiş saat sayını hesabla.

# %%
# Kodunu bura yaz:

# %% [markdown]
# ### Tapşırıq 4
#
# Bir kinoda biletlər 100-dən başlayır, 150-yə qədər gedir.
#
# Bu bilet nömrələrindən ibarət array yarat.

# %%
# Kodunu bura yaz:

# %% [markdown]
# ### Tapşırıq 5
#
# temperatur 0°C-dən 100°C-ə qədər 10 bərabər aralıqlarla yarat

# %%
# Kodunu bura yaz:

# %% [markdown]
# ### Tapşırıq 6
#
# 1 milyonluq ədəd yarat və cəmini hesabla

# %%
# Kodunu bura yaz:

# %% [markdown]
# ### Tapşırıq 7
#
# 3 tələbənin 4 fənndən aldığı qiymətlər aşağıdakı verilib:
#
# ```
# [[85, 90, 78, 92],
#  [70, 88, 95, 60],
#  [55, 72, 80, 88]]
# ```
#
# Bu datadan 2D array yarat. Sonra onun shape-ini, ndim-ini və size-ini göstər.

# %%
# Kodunu bura yaz:
data = [[85, 90, 78, 92],
 [70, 88, 95, 60],
 [55, 72, 80, 88]]

# %% [markdown]
# ### Tapşırıq 8 — Şəkil pikseli kimi reshape
#
#
#
# Aşağdakı array-i 3x4 ölçülü matrix-ə çevir.

# %%
# Kodunu bura yaz:

# %% [markdown]
# ### Tapşırıq 9
#
# ```
# [[1, 2, 3],
#  [4, 5, 6],
#  [7, 8, 9]]
# ```
#
# Bu array-i 1D-yə çevir

# %%
data = [[1, 2, 3],
 [4, 5, 6],
 [7, 8, 9]]

# %% [markdown]
# ### Tapşırıq 10
#
# Sütunlar: Ana dili, Riyaziyyat, Fizika.
# Sətirlər: tələbələr.
#
# ```
# [[80, 90],
#  [70, 85],
#  [95, 60]]
# ```
#
# Bu matrixi elə etki, sütunlar tələbə, sətirlər fənn olsun.

# %%
data = [[80, 90],
 [70, 85],
 [95, 60]]

# %% [markdown]
# ### Tapşırıq 11
#
# 3 şəhər və 2 gün matrix tipində array yarat

# %%
# Kodunu bura yaz:

# %% [markdown]
# ### Tapşırıq 12
#
# şirkətin 4 işçisinin 3 aylıq maaşları:
#
# ```
# [[1200, 1300, 1250],
#  [1500, 1600, 1550],
#  [900,  950,  920],
#  [2000, 2100, 2050]]
# ```
#
# 1. Yalnız 2-ci ayın  maaşlarını göstər
# 2. Yalnız 3-cü işçinin aylarını göstər

# %%
# Kodunu bura yaz:

# %% [markdown]
# ### Tapşırıq 13
#
# Bir mağazada məhsul qiymətləri: `[120, 45, 300, 89, 15, 200, 60, 175]`
#
# Qiyməti 100-dən aşağı olan bütün məhsulları Boolean indexing ilə tap.

# %%
# Kodunu bura yaz:

# %% [markdown]
# ### Tapşırıq 14
#
# Tələbə qiymətləri: `[55, 72, 43, 90, 38, 65, 80, 47]`
#
# Keçid balı 50-dir. Keçən tələbələri və Keçməyənləri ayrı ayrı göstər

# %%
# Kodunu bura yaz:

# %% [markdown]
# ### Tapşırıq 15
#
# Həftəlik satış: `[1500, 2300, 1800, 3200, 2700, 4100, 900]`
#
# Yalnız son 3 günün satışını göstər

# %%
# Kodunu bura yaz:

# %% [markdown]
# ### Tapşırıq 16
#
# Günlük temperatur: `[22, 35, 28, 41, 19, 38, 30, 44, 27]`
#
# 40 dərəcədən yuxarı olan temperatur varsa ekranda xəbərdarlıq yazılsın

# %%
# Kodunu bura yaz:

# %% [markdown]
# ### Tapşırıq 17
#
# 5x5 ölçülü 25dənəli array yarat.
#
# Onun ortasından 3x3-lük arrayı çıxart və ekranda göstər

# %%
# Kodunu bura yaz:

# %% [markdown]
# ### Tapşırıq 18
#
# Məhsulların əsas qiymətləri: `[100, 250, 80, 430, 60]`
#
# Bu qiymətlərə 18% ƏDV əlavə elə

# %%
# Kodunu bura yaz:

# %% [markdown]
# ### Tapşırıq 19
#
# Bir robot düz xətt üzrə `[3, 4]` koordinatına gedir. Başlanğıc nöqtəsi `[0, 0]`-dır.
#
# Koordinatlar arasındakı Evklid (vektor) məsafəsini hesabla

# %%
# Kodunu bura yaz:

# %% [markdown]
# ### Tapşırıq 20
#
# Kart hesablarının balansları: `[-200, 500, -50, 1200, -800, 300]`
#
# Mənfi balansları müsbət et — borcun miqdarını göstərmək üçün.

# %%
# Kodunu bura yaz:

# %% [markdown]
# ### Tapşırıq 21
#
# maaşlar verilib (3, 4)
#
# ```
# [[1000, 1200, 900, 1100],
#  [1500, 1400, 1600, 1300],
#  [800,  850,  900,  750]]
# ```
#
# Hər komandaya (cerge) fərqli bonus ver: `[100, 200, 50]`

# %%
# Kodunu bura yaz:

# %% [markdown]
# ### Tapşırıq 22
#
# Bir şirkətin son 5 ilin qazancı: `[10, 12, 9, 15, 18]`
#
# Hər ilin əvvəlki ilə nisbətdə neçə faiz artdığını hesabla (ilk il üçün hesab etməyə ehtiyac yoxdur).

# %%
# Kodunu bura yaz:

# %% [markdown]
# ### Tapşırıq 23 — İmtahan statistikası
#
# Sinifin imtahan balları: `[72, 85, 91, 60, 78, 95, 55, 88, 74, 83]`
#
# Orta bal, median, standart sapma, ən yüksək və ən aşağı balı hesabla.

# %%
# Kodunu bura yaz:

# %% [markdown]
# ### Tapşırıq 24 — Ən yaxşı və ən pis satış günü
#
# Satış rəqəmləri:
# `[320, 450, 280, 510, 390, 620, 210, 480, 350, 290, 540, 410, 680, 230]`
#
# Ən çox satış olan günün indeksini və ən az satış olan günün indeksini tap

# %%
# Kodunu bura yaz:

# %% [markdown]
# ### Tapşırıq 25
#
# 4 tələbənin 5 fənndən ibarət balları:
#
# ```
# [[80, 90, 75, 85, 70],
#  [60, 55, 70, 65, 80],
#  [95, 88, 92, 97, 90],
#  [50, 60, 45, 55, 65]]
# ```
#
# Hər tələbənin orta balını hesabla.

# %%
# Kodunu bura yaz:

# %% [markdown]
# ### Tapşırıq 26 — Hər fənn üzrə ən yüksək bal
#
# Yuxarıdakı eyni qiymət matrixindən istifadə et.
#
# Bu dəfə hər fənnin (hər sütunun) ən yüksək balını tap.

# %%
# Kodunu bura yaz:

# %% [markdown]
# ### Tapşırıq 27
#
# İki məhsulun 10 günlük satış rəqəmləri:
#
# - Məhsul A: `[100, 102, 99, 101, 100, 103, 98, 101, 100, 102]`
# - Məhsul B: `[80, 130, 60, 150, 90, 120, 50, 140, 110, 70]`
#
# Hər ikisinin sabitliyini hesabla. Hansı məhsulun satışı daha sabitdir? `var`

# %%
# Kodunu bura yaz:

# %% [markdown]
# ### Tapşırıq 28 — Z-score normallaşdırması
#
# Tələbə balları: `[55, 70, 80, 65, 90, 75, 60, 85]`
#
# Z-score formulası: `(x - mean) / std`
#
# Hər balın Z-score-unu hesabla. Bu normallaşdırma nə üçün istifadə olunur?

# %%
# Kodunu bura yaz:

# %% [markdown]
# ### Tapşırıq 29
#
# - 1-ci həftə: `[500, 620, 480, 700, 550, 610, 430]`
# - 2-ci həftə: `[670, 590, 720, 800, 630, 540, 490]`
#
# Bu iki array-i birləşdirərək bütün ay üçün tək array yarat.

# %%
# Kodunu bura yaz:

# %% [markdown]
# ### Tapşırıq 30
#
# - Yanvar: `[1200, 1500, 1100]`
# - Fevral: `[1400, 1300, 1600]`
# - Mart: `[1100, 1700, 1250]`
#
# bu arraylardan 3x3 array yarat `vstack`

# %%
# Kodunu bura yaz:

# %% [markdown]
# ### Tapşırıq 31
#
# - İşçi ID: `[101, 102, 103, 104]`
# - Maaş: `[2500, 3200, 1800, 4100]`
#
# Bu iki array-i yan-yana birləşdir

# %%
# Kodunu bura yaz:

# %% [markdown]
# ### Tapşırıq 32 - İli rüblərə böl
#
# `[100,150,130,200,180,210,190,220,170,160,240,260]`
#
# Bu array-i hər biri 3 elementdən ibarət 4 bərabər hissəyə böl

# %%
# Kodunu bura yaz:

# %% [markdown]
# ### Tapşırıq 33
#
# 2 rəqibin 5 ay üzrə satışları:
#
# - Şirkət A: `[300, 420, 380, 510, 460]`
# - Şirkət B: `[350, 400, 410, 490, 480]`
#
# bunları birləşdirərək `(2, 5)` ölçülü matrix yarat

# %%
# Kodunu bura yaz:

# %% [markdown]
# ### Tapşırıq 34
#
# Bir zər 1000 dəfə atılır. 1-dən 6-ya qədər rəqəmlərdən ibarət 1000 elementlik random array yarat.
#
# Hər rəqəmin neçə dəfə çıxdığını hesabla.

# %%
# Kodunu bura yaz:

# %% [markdown]
# ### Tapşırıq 35
#
# Orta balı 70, standart aralığı 10 olan normal paylanmadan 50 tələbənin balını yarat.
#
# Bu datanın ortasını, min və max dəyərini göstər.

# %%
# Kodunu bura yaz:

# %% [markdown]
# ### Tapşırıq 37 — Vektor uzunluğu (norm)
#
# Bir GPS cihazı iki nöqtəni qeyd edir:
#
# -  `[1, 2, 3]`
# -  `[4, 6, 3]`
#
# İki nöqtə arasındakı məsafəni hesabla.

# %%
# Kodunu bura yaz:

# %% [markdown]
# ### Tapşırıq 38
#
#
# `[22.5, np.nan, 24.0, np.nan, 21.8, 23.5, np.nan, 25.0]`
#
# orta temperaturu hesabla

# %%
# Kodunu bura yaz:

# %% [markdown]
# ### Tapşırıq 39
#
#
# `[100.0, np.nan, 95.5, np.nan, np.nan, 102.3, 98.7]`
#
# `nan` dəyərlərini sıfırla əvəz et

# %%
# Kodunu bura yaz:

# %% [markdown]
# ### Tapşırıq 40
#
# Aşağıdakıları həll et
#
# 1. Neçə `nan` olduğunu tap
# 2. `nan` dəyərləri orta dəyər ilə əvəz et
# 3. Bütün dəyərləri 0–40 aralığına çevir
# 4. Təmizlənmiş datanın orta, min, max və std-sini hesabla

# %%
# Kodunu bura yaz:
