# %% [markdown]
# # NumPy Ümumi Tapşırıqlar (Dərs 5-ə kimi)

# %% [markdown]
# ### Tapşırıq 1
# 5 fərqli ədəddən ibarət bir list yaradın. Bu listi NumPy array-inə çevirin. Yaradılmış array-in ölçüsünü (`shape`), ölçü sayını (`ndim`) və məlumat tipini (`dtype`) terminalda göstərin

# %%
# kodu burdan yaz

# %% [markdown]
# ### Tapşırıq 2
# `np.linspace()` funksiyasından istifadə edərək 0 ilə 50 arasında bərabər aralıqlı 5 ədəd yaradın. Bu ədədlərin ilkin data tipini yoxlayın

# %%
# kodu burdan yaz

# %% [markdown]
# ### Tapşırıq 3
# `np.arange()` funksiyası ilə 1-dən 12-yə qədər (12 daxil olmaqla) ardıcıl ədədlərdən ibarət 1D array yaradın. Bu array-i `3x4` ölçülü 2D matrixə çevirin. Sonda həmin matrixin tərsinə çevrilmiş versiyasını terminalda göstərin

# %%
# kodu burdan yaz

# %% [markdown]
# ### Tapşırıq 4
# Bir mağazadakı 4 məhsulun qiymətlərini NumPy array şəklində qeyd edin. Bütün məhsulların qiymətini inflyasiyaya görə 1.2 dəfə artırın. Sonra Python-un `f-string` formatından istifadə edərək ilkin və yeni qiymətlərin cəmini göstərin.

# %%
# kodu burdan yaz

# %% [markdown]
# ### Tapşırıq 5
# `3x3` ölçülü bir matrix yaradın. Python-un `for` dövründən (`Loops`) istifadə edərək bu matrixin hər bir sətrin ilk iki elementini ekrana göstərin

# %%
# kodu burdan yaz

# %% [markdown]
# ### Tapşırıq 6
# Tələbələrin imtahan nəticələrindən ibarət 1D array verilib. Boolean Indexing-dən istifadə edərək yalnız 51-dən böyük və ya bərabər olan (keçən) balları filterləyin və yeni bir array-ə təyin edin. Əgər keçən tələbə sayı 0-dan çoxdursa, ekrana "Dərslər öyrədildi!" əks halda "Yenidən imtahan!" sözlərini `if-else` şərti yaradın

# %%
import numpy as np

ballar = [45, 67, 82, 30, 51, 90, 49]

# kodu burdan yaz

# %% [markdown]
# ### Tapşırıq 7
# Bir şirkətin 6 aylıq gəlir/çıxış balansı ədədlərlə verilmişdir (müsbət gəlir, mənfi zərər). `np.where()` funksiyasından istifadə edərək müsbət dəyərlərin yerinə `1`, mənfi dəyərlərin yerinə isə `0` qoyun. Alınan yeni arrayi terminalda göstərin

# %%
import numpy as np

balans = [1500, -200, 3000, -1500, 4000, 0]

# kodu burdan yaz

# %% [markdown]
# ### Tapşırıq 8
# `statistika_hesabla` adlı bir Python funksiyası (`def`) yaradın. Bu funksiya parametr kimi bir NumPy array-i qəbul etməlidir. Funksiyanın daxilində array-in minimum, maksimum və median dəyərlərini hesablayın və nəticəni bir geri qaytarın (`return`). Daha sonra həmin nəticəni terminalda göstərin

# %%
import numpy as np

def statistika_hesabla(arr):
    return

# %% [markdown]
# ### Tapşırıq 9
# Bir həftəlik səhmlərin qiymətləri array-də verilmişdir. Ən yüksək qiymətin (`argmax`) və ən aşağı qiymətin (`argmin`) indekslərini tapın. Python-un `enumerate()` funksiyasından istifadə edərək həmin indekslərə uyğun gələn günlərin adını terminalda göstərin.

# %%
import numpy as np

gunler = ["Bazar ertəsi", "Çərşənbə axşamı", "Çərşənbə", "Cümə axşamı", "Cümə"]
qiymetler = np.array([150, 165, 142, 178, 160])

# %% [markdown]
# ### Tapşırıq 10
# Python-un `input()` funksiyası ilə istifadəçidən bir qüvvət dəyəri alın (məsələn: 2 və ya 3). Həmin ədədi tam ədədə çevirin. Sonra verilmiş NumPy array-indəki mənfi ədədlərin modulunu tapın (`np.abs`), daha sonra isə bütün elementləri istifadəçinin daxil etdiyi dəyər sayı qədər qüvvətə yüksəldin (`np.power`).

# %%
import numpy as np

data = np.array([-2, 3, -4, 5])

# %% [markdown]
# ### Tapşırıq 11
# **Təsvir:** Əlimizdə koordinat nöqtələrindən ibarət unikal (təkrarlanmayan) bir Python Set data tipi var. Bu Set daxilindəki elementləri əvvəlcə List-ə , sonra NumPy matrisinə (2D Array) çevirin. Son olaraq matrixin mərkəzindəki elementi indeksləmə ilə terminalda göstərin.

# %%
import numpy as np

# Unikal koordinat nöqtələri
koordinat_seti = {(1, 2, 3), (4, 5, 6), (7, 8, 9)}

# %% [markdown]
# ### Tapşırıq 12
# 3 tələbənin 3 fərqli fənn üzrə ballarından ibarət `3x3` matrix verilib. Hər fənnin (yəni hər sütunun: `axis=0`) ortalama (`mean`) balını tapın. Əgər hər hansı bir fənnin ortalaması 70-dən aşağıdırsa, Terminalda "Tələbə oxumur!" yazılsın.

# %%
import numpy as np

# rows -> Tələbələr, columns -> Fənlər
imtahanlar = np.array([[80, 50, 95], 
                       [75, 60, 80], 
                       [90, 45, 85]])

# %% [markdown]
# ### Tapşırıq 13
# 10 rəqəmdən ibarət 1D array verilib. Python-un `while` dövründən istifadə edərək, array-in ümumi cəmi (`sum`) 150-dən kiçik olduğu müddətcə hər dövrdə array-in bütün elementlərinin üzərinə `5` əlavə edin. Cəm 150-ni keçdikdə dövrü dayandırın (`break`) və həmçinin ümumi dövr sayınıda tapın və terminalda göstərin.

# %%
import numpy as np

arr = np.array([5, 10, 8, 12, 3, 7, 14, 9, 2, 11])
dovr_sayi = 0
